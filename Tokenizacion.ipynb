# %%
import nltk 
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lugoc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\lugoc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\lugoc\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text = "Hola, ¿Como estas?"
tokens = text.split()
print(tokens)
# Out:
# ['Hola,', '¿Como', 'estas?']

# %%
text = "Hola, ¿Como estas?"
text = text.lower()
print(text)
tokens = text.split()
print(tokens)
# Out:
# hola, ¿como estas?
# ['hola,', '¿como', 'estas?']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('spanish'))
print(stop_words)
# Out:
# {'mía', 'pero', 'estuvierais', 'esté', 'serán', 'hay', 'mi', 'habrán', 'sus', 'estaríamos', 'mío', 'eres', 'tuyos', 'fuiste', 'nada', 'nuestra', 'estuvieron', 'nuestros', 'seamos', 'qué', 'míos', 'sentido', 'poco', 'teníais', 'habría', 'porque', 'fuese', 'hubieras', 'estuvimos', 'hubieses', 'estabas', 'esos', 'tenidas', 'su', 'más', 'he', 'te', 'será', 'hubieron', 'suyo', 'estados', 'estarían', 'esto', 'sobre', 'siente', 'le', 'sintiendo', 'fuésemos', 'y', 'tened', 'tuviéramos', 'en', 'estaremos', 'sentid', 'estuvisteis', 'estuvieran', 'eras', 'durante', 'la', 'sería', 'habida', 'estáis', 'tenga', 'tengáis', 'seríamos', 'sí', 'son', 'tuve', 'ha', 'tenías', 'tendrán', 'tendrá', 'ni', 'hubiéramos', 'estemos', 'fuéramos', 'tuya', 'otra', 'entre', 'sentidos', 'tendré', 'habrían', 'todo', 'tuviera', 'sentidas', 'unos', 'eso', 'tuvieron', 'seré', 'nos', 'estén', 'habrías', 'habíamos', 'estuviera', 'tú', 'como', 'mis', 'suya', 'que', 'tenido', 'fuimos', 'serían', 'fuerais', 'fueran', 'sin', 'algunas', 'yo', 'seremos', 'suyas', 'tendría', 'seas', 'tuvisteis', 'estaba', 'habían', 'hubierais', 'tendréis', 'habríamos', 'tus', 'cual', 'habidos', 'estuviéramos', 'hayas', 'seréis', 'muy', 'muchos', 'vosotros', 'quien', 'tiene', 'erais', 'tenida', 'este', 'ese', 'estuviésemos', 'estará', 'las', 'estado', 'él', 'nosotros', 'todos', 'fueras', 'somos', 'estoy', 'habréis', 'nosotras', 'has', 'de', 'hubiésemos', 'había', 'ellas', 'ella', 'tuviste', 'estuviese', 'sean', 'tuvierais', 'el', 'hubiera', 'tengan', 'les', 'lo', 'hasta', 'hube', 'estando', 'con', 'habiendo', 'otras', 'suyos', 'fuera', 'éramos', 'tenía', 'teníamos', 'quienes', 'no', 'están', 'estaré', 'fue', 'tuyo', 'habré', 'tenían', 'mías', 'hubieseis', 'tendremos', 'para', 'tendrás', 'estás', 'estaríais', 'estuve', 'ante', 'mí', 'seríais', 'se', 'estas', 'estamos', 'nuestro', 'está', 'hemos', 'fuisteis', 'vuestros', 'tenéis', 'estés', 'tengamos', 'uno', 'tuvimos', 'estaréis', 'eran', 'tendrían', 'los', 'fuesen', 'hayamos', 'hubisteis', 'algunos', 'estaban', 'esa', 'fueses', 'me', 'ya', 'vosotras', 'estaría', 'fueron', 'habéis', 'vuestro', 'algo', 'sea', 'estuvo', 'donde', 'tienen', 'al', 'estadas', 'habrá', 'haya', 'contra', 'han', 'hubiese', 'estarías', 'del', 'estarán', 'o', 'soy', 'estuviesen', 'tanto', 'estábamos', 'otro', 'también', 'desde', 'habríais', 'serás', 'estuvieras', 'a', 'cuando', 'os', 'tuvieseis', 'tuvieras', 'estada', 'habidas', 'habremos', 'habido', 'tengas', 'ti', 'mucho', 'tienes', 'estéis', 'era', 'e', 'nuestras', 'habíais', 'hubiesen', 'esas', 'tendríais', 'sois', 'tuvieses', 'esta', 'tuyas', 'hubiste', 'tengo', 'estuvieseis', 'habrás', 'tuviesen', 'tuviésemos', 'hayáis', 'estad', 'hubo', 'sentida', 'tenemos', 'estuviste', 'es', 'vuestras', 'una', 'tuviese', 'fueseis', 'otros', 'estuvieses', 'hayan', 'antes', 'estar', 'tuvo', 'ellos', 'serías', 'un', 'seáis', 'por', 'fui', 'tuvieran', 'tu', 'hubieran', 'estos', 'vuestra', 'hubimos', 'tendríamos', 'estarás', 'tenidos', 'estabais', 'teniendo', 'habías', 'tendrías'}

# %%
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['el', 'gato', 'es', 'negro', 'y', 'el', 'perro', 'es', 'blanco']

# %%
neaked_text = [word for word in tokens if not word in stop_words]

# %%
print(neaked_text)
# Out:
# ['gato', 'negro', 'perro', 'blanco']

# %%
text = text.lower()
tokens = word_tokenize(text)
neaked_text = [word for word in tokens if not word in stop_words]
print(neaked_text)
# Out:
# ['gato', 'negro', 'perro', 'blanco']

# %%
from nltk.stem import SnowballStemmer

#crear el stemmer en español
stemmer = SnowballStemmer('spanish')

#probarla con la palabra corriendo
print(stemmer.stem('caminando'))
print(stemmer.stem('caminar'))
print(stemmer.stem('camino'))
# Out:
# camin
# camin
# camin

# %%
# !python -m spacy download es_core_news_sm -q
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %%
import spacy 
# cargar el modelo en español
nlp = spacy.load('es_core_news_sm')
#crear un documento
doc = nlp('caminar caminando caminó')
#imprimir el texto y el lema de cada token
for token in doc:
    print(token.text, "->", token.lemma_)
# Out:
# caminar -> caminar
# caminando -> caminar
# caminó -> caminar
