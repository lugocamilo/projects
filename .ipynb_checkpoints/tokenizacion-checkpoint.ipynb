# %%
text = "Hello, ¿how are you?"
tokens = text.split()
print(tokens)
# Out:
# ['Hello,', '¿how', 'are', 'you?']

# %%
text = "Hello, ¿How are you?"
text = text.lower()
print(text)
tokens = text.split()
print(tokens)
# Out:
# hello, ¿how are you?
# ['hello,', '¿how', 'are', 'you?']

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\lugoc\anaconda3\envs\practica\Lib\site-packages (3.9.4)
# Requirement already satisfied: click in C:\Users\lugoc\anaconda3\envs\practica\Lib\site-packages (from nltk) (8.3.3)
# Requirement already satisfied: joblib in C:\Users\lugoc\anaconda3\envs\practica\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\lugoc\anaconda3\envs\practica\Lib\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in C:\Users\lugoc\anaconda3\envs\practica\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\lugoc\anaconda3\envs\practica\Lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lugoc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\lugoc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'during', 'that', 'were', "aren't", 'each', "didn't", 'for', "don't", 'herself', "that'll", 'so', 'aren', "isn't", 'some', 'any', 'is', 'been', 'd', "haven't", 'there', 'his', "mightn't", 'just', 'your', 'haven', 'out', 'an', 'no', "couldn't", 'doesn', 'has', 'her', 'did', 'own', "you've", 'them', 'if', 'll', 'before', 'me', 'until', 'having', 'other', 'then', "won't", 'and', "wasn't", 'wouldn', 'what', 'my', 're', 'ain', "we've", 'i', "shan't", 'to', "i've", 's', 'should', 'him', "we'll", "he'd", 'he', 'because', 'was', "she'd", 'of', 'doing', 'from', 'when', 'had', "doesn't", 'very', 'does', 'down', 'have', 'too', "we'd", 'those', 'or', 'yourself', 'further', "they'd", "needn't", 've', 'am', 'while', 'why', 'up', 'itself', 'which', 'after', 'hers', "we're", 'by', 'you', 'a', "they'll", 'with', "it's", 'she', 'how', 'both', "it'll", 'off', 'won', 'o', "should've", 'm', 'between', "i'm", 'weren', 'all', 'can', 'didn', 'shouldn', 'ourselves', 'couldn', 'this', "you're", 'who', 'do', "i'll", 'ma', 'yourselves', "wouldn't", 'myself', 'wasn', 'being', 'their', 'not', 'against', 'ours', "he'll", 'theirs', "i'd", 'more', 'needn', 'through', 'don', 'mustn', 'the', "they're", 'above', "she's", 'themselves', 'shan', "weren't", 'these', 'same', 'now', 'below', 'hasn', 'will', 'on', "you'll", 'yours', 'under', "shouldn't", 'it', 'again', 'few', 'mightn', 'nor', 'over', 'y', "hasn't", 'such', "they've", 'we', 'isn', "hadn't", 'in', "you'd", 'once', 't', 'most', 'into', 'about', 'are', 'at', 'be', 'whom', 'himself', 'they', 'than', 'only', 'hadn', 'here', 'our', 'as', "she'll", "mustn't", 'where', 'its', 'but', "it'd", "he's"}

# %%
text = "The cat is black and the dog is white".lower()
not_leaked_text = "The cat is black and the dog is white"

# %%
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['the', 'cat', 'is', 'black', 'and', 'the', 'dog', 'is', 'white']

# %%
leaked_text = [word for word in tokens if not word in stop_words]
print(leaked_text)
print(not_leaked_text)
# Out:
# ['cat', 'black', 'dog', 'white']
# The cat is black and the dog is white

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\lugoc\AppData\Roaming\nltk_data...
# True

# %%
from nltk.stem import SnowballStemmer

#Crear el stemmer en ingles
stemmer = SnowballStemmer('english')

#Probar con una palabra
print(stemmer.stem('walking'))
print(stemmer.stem('to walk'))
print(stemmer.stem('path'))
# Out:
# walk
# to walk
# path

# %%
pip install spacy -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download es_core_news_sm -q
# Out:
# [+] Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
